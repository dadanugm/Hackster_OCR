# %%
import pyttsx3
import os
import time
import pytesseract
import cv2
from IPython.display import Audio
from threading import Thread
from multiprocessing import Process
from PIL import Image
from gtts import gTTS
from playsound import playsound
from kv260 import BaseOverlay
from pynq.lib.pmod.pmod_io import Pmod_IO

#image_path = 'text_ind.jpg'
image_path = 'test_cam.jpg'
threshold = True
blur = True
text = ""
start = False
play = False

############# GPIO #####################
base = BaseOverlay('base.bit')
SW1=Pmod_IO(base.PMODA,index=0,direction='in')
SW2=Pmod_IO(base.PMODA,index=4,direction='in')
SW3=Pmod_IO(base.PMODA,index=1,direction='in')
SW4=Pmod_IO(base.PMODA,index=5,direction='in')

######## get image from camera #########
def get_image():
    print("get image")
    cam = cv2.VideoCapture(0)
    cam.set(cv2.CAP_PROP_FRAME_WIDTH,1280)
    cam.set(cv2.CAP_PROP_FRAME_HEIGHT, 1024)
    #cam.open(0, cv2.CAP_ANY)
    ret, img = cam.read()
    image = cv2.rotate(img, cv2.cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite('test_cam.jpg', image)
    print("get image done")
    #time.sleep(5)

########## Convert image to text ##############
def get_text():
    global text
    print("convert image to text")
    img = cv2.imread(image_path)
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    if threshold == True:
        gray_img = cv2.threshold(gray_img, 0, 225, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
    elif blur == True:
        gray_img = cv2.medianBlur(gray_img, 5)
    cv2.imwrite('grey_img.jpg', gray_img)
    filename = "{}.png".format(os.getpid())
    cv2.imwrite(filename, gray_img)

    text = pytesseract.image_to_string(Image.open(filename))
    os.remove(filename)
    print(text)
    print("convert image to text done")

#########  TEXT to Speech ###############
def text_to_sound():
    global text
    print("convert text to MP3")
    tts = gTTS(text, lang='id')
    tts.save('text_gtts.mp3')
    print("convert text to MP3 done")

######### PLAYING Sound ###############
#def play_sound(filename):
#    global play
#    #play sound
#    while(True):
#        if play == True:
#            play = False
#            print("now playing sound",filename)
#            #playsound(filename)
#            Audio("Test_playsound.mp3",autoplay=True)

#pl_sound = Process(target=play_sound, args=('text_gtts.mp3',))

######### Flow Program ###############
def flow_program():
    global start, play
    while(True):
        if start == True:
            start = False
            get_image()
            get_text()
            text_to_sound()
            Audio("Test_playsound.mp3",autoplay=True)
            #play = True #start playing sound
            #if pl_sound.is_alive() == False:
                #pl_sound.start()
            


############### SCAN GPIO ############
def scan_gpio1():
    global play, start
    while(True):
        time.sleep(0.5)
        val = SW1.read()
        if val == 1:
            start = True
            print("button 1 pressed")
            print("start:",start)

def scan_gpio2():
    global play, start, pl_sound
    while(True):
        time.sleep(0.5)
        val = SW2.read()
        if val == 1:
            print("button 2 pressed")
            start = False
            play = False
            #kill thread
            #pl_sound.terminate()

def scan_gpio3():
    while(True):
        time.sleep(0.5)
        val = SW3.read()
        if val == 1:
            print("button 3 pressed")

def scan_gpio4():
    while(True):
        time.sleep(0.5)
        val = SW4.read()
        if val == 1:
            print("button 4 pressed")

if __name__ == "__main__":
    # multitrhreading
    thread1 = Thread(target=flow_program, name='main thread')
    #thread2 = Thread(target=play_sound, name='playing sound', args=('text_gtts.mp3',))
    #scan GPIO
    th_gpio1 = Thread(target=scan_gpio1, name='scan gpio 1')
    #th_gpio2 = Thread(target=scan_gpio2, name='scan gpio 2')
    #th_gpio3 = Thread(target=scan_gpio3, name='scan gpio 3')
    #th_gpio4 = Thread(target=scan_gpio4, name='scan gpio 4')
    # Start threads
    thread1.start()
    time.sleep(1)
    #thread2.start()
    #time.sleep(1)
    th_gpio1.start()
    time.sleep(1)
    #th_gpio2.start()
    #time.sleep(1)
    #th_gpio3.start()
    #time.sleep(1)
    #th_gpio4.start()
    #time.sleep(1)
    print("device ready")
# Out:
# device ready
# button 1 pressedget image
#
# start: False
# get image done
# convert image to text
# (Gene) Oe
# . in sampal dengan Harn Jumat, mulal dar
#
# PERTAMA dapat menugaskan PIHAK KEDUA untuk beker
# peda hari kerja bias meupun pada hen Wour-dan untuk itu PIHA
# yar a pah fembur sesuai dengan peraturan ketenagakerjaan yar
#
#
#
#
# nkan meninggalkan pekeraan dalam han dan waktu kerja ses
# ini untuk melakukan aktifitas lain yang bere
#
# ‘ pe disebul dalam yat (1) dan (2) Pasal
# . yew pana di luar pekenaan dari Perusahaan.
# lakukan pelanggaran atas ayat (4) Pasa
#
# pekerjas' tambe
# [A vecara sah dan meyakinkan me
# ih) Me eteiah diDerikan Po tan tertulis maupun lisan, make PIHAK PERTAMA berhak u
# ow ganniti Perjanjian ini tanpa adanya kewajiban memberikan kompensasi apapun.
# Pasal-6
# TATA TERTIB
# | Selama perlakuny@ Perjanjian inl, PIHAK KEDUA wajib mentaati Peraturan yang berls
# Perusahaan.
# bocorkan rahasia Pi
#
# tL), PIHAK KEDUA tidak akan mem
# un tidak langsung, baik sedang menjalal
#
# erusahaan dengan cara apapur
# nkan masa kontrak maupun suda
# ng dilarang balk dalam perun
#
# langsung maup'
# lagi terikat kontrak; atau metakukan perbuatan ya
# ketenagakejaan maupun perundangan dan peraturan lainnya yang berlaku di negara R
# Indonesia.
# erusahaan lain secara ber
#
# 3) PIHAK KEQUA tidak diperkenankan terdaftar bekerja dalam p
# dalam jangka waktu kontrak yang tercantum dalam Pasal-1 Ayat (1) Perjanjian ini.
# Ri
#
# gambil bag dalam suatu projek di luar,
#
#
#
#
#
#
#
#
#
# peraturan
# a Republik
#
# eae
# a perjanjian kerja set
# Juni 2020.
#
#
#
# 2. yi er ; .
#
# (2.) Pefanfan iri merupakan porpenangen jangka waktu perjen)
#
# voor -M/20 yang ditandatangani pada tanggal 26
# Pasal-5
# PENUTUP
#
# GQ) H :
# een menurut Perjanjian ini akan _berakhir
# a berlaku tersebut pada Pasal-1 Perjanjian inl.
# an in! untuk Jang
#
# {2.) Bila dipend:
# maksimal Figen a PIHAK PERTAMA dapat memperpanjang Perjanji
# un lamanya, dan akan dilakukan secara tertulis ataupun lisan palit
#
#
#
#
#
# demi hukum, bersamaan
#
# convert image to text done
# convert text to MP3
# convert text to MP3 done
