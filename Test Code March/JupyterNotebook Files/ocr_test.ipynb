# %%
import pyttsx3
import os
import time
import pytesseract
import cv2
import os
from PIL import Image
from gtts import gTTS
from playsound import playsound
from kv260 import BaseOverlay
from pynq.lib.pmod.pmod_io import Pmod_IO

#pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files/Tesseract-OCR/tesseract.exe'
#image_path = 'text_ind.jpg'
image_path = 'test_cam.jpg'
threshold = True
blur = True
text = ""

base = BaseOverlay('base.bit')
led=Pmod_IO(base.PMODA,index=0,direction='out')
led.write(0)

######## TEST CAMERA #########
def test_cam():
    cam = cv2.VideoCapture(0)
    cam.set(cv2.CAP_PROP_FRAME_WIDTH,1280)
    cam.set(cv2.CAP_PROP_FRAME_HEIGHT, 1024)
    #cam.open(0, cv2.CAP_ANY)
    ret, img = cam.read()
    image = cv2.rotate(img, cv2.cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite('test_cam.jpg', image)
    #time.sleep(5)

def test_tesseract():
    global text
    img = cv2.imread(image_path)
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    if threshold == True:
        gray_img = cv2.threshold(gray_img, 0, 225, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
    elif blur == True:
        gray_img = cv2.medianBlur(gray_img, 5)
    cv2.imwrite('grey_img.jpg', gray_img)
    filename = "{}.png".format(os.getpid())
    cv2.imwrite(filename, gray_img)

    text = pytesseract.image_to_string(Image.open(filename))
    os.remove(filename)
    print(text)
    print("done")

def test_gtts():
    global text
    tts = gTTS(text, lang='en')
    tts.save('test_gtts.mp3')
    #play sound
    playsound('test_gtts.mp3')
    print("done")

test_cam()
test_tesseract()
test_gtts()
# Out:
# . ’ ae ak at
# wa 4 - ook t
#
# . Pan athey
# er 4
# a . ee .
# sake tys es
# itm se RO . SH AAR gy
# wa aT ; ry » koe . ‘ Me Cah see .
# s35° Ay var va a . ;
# Sa rer ra arr ran . © va ms i
# 3d cad . soe he " at an e ae
# Re A Sar ygae PAT ETT Ra TP oa ‘ “
# remutusar MDL gd 88 go SULA. FS NS Boa sa Yaka sey
# 4 ren aka Te Ta ATR TR Tes * “TES vay tg POT Te abty
# a keganya $873 (MR ARIA  S ath 8 kee oy te neha ag ee
# ir
# PERTAMA
# ma 7 vot gk Me beam ba? “ ny P fs
# (|) Pemutusan hubungan kena seiana “Naha ah gg ER TaMa yak apatila PIA
#
# (6)
#
# ()
#
# (2)
#
# @)
# (4)
#
# KEDUA melanggar penanjian keqa 2 earua perature perusahaanr meianggar peraturs
# pemenntah, dan atau penilaian has kinera ya7Q dak memuaskar Selelan dibenkan peer
# pelatihan untuk mendukung kinena
#
# Pemutusan hubungan kena selama masa kontrak oleh PIHAK PERTAMA dikarenakan sebat
# sebab yang disebutkan pada ayat (5) Pasai im PIHAK PERTAMA tidak diwayibkan unte
# membayarkan apapun kepada PIHAK KEDUA
#
# Pasal-3
# TUGAS DAN PENEMPATAN
#
# PIHAK PERTAMA mempekenakan PIHAK KEDUA sebaga
#
# 11 Jabatan Embedded System Engineer
# 12 Grade 3A
# 13 Departement M2M
#
# 14 Bertanggung-jawab pada COO M2mM
# 15 Tugas dan tanggung jawab Dyelaskan oleh atasan
# 16 Penempatan Kantor Pusat di Bandung
#
# PIHAK KEDUA bersadia melaksanakan tugas pekenaan yang dibenkan oleh PIHAK PERTAMA
# dengan Sebaik-baiknya
#
# PIHAK PERTAMA berhak memperoteh hasil kena yang terbaik dan PIHAK KEDUA
#
# Penibahan Penempatan tu
# jas atas dibenkan oleh
# PIHAK PERTAMA eas a akibat dan tugas dan tanggung yawab yang di
#
# HAK KEDUA akan disesuatkan apabila diperiukan
#
# Pasat-4
# UPAH DAN F.
# PIRAK PERTAMA ee AN FASILITAS
#
# upah bersih ke PIHAK KE(TNJA sebesar Rp 6 "22 812
# | (enam jute tuyuh ratus dua puluh pada ECA se
#
# Paak Pen, dua nbu delapan ratus dua belas nuigrah: sehap bular
#
# Shastan dan upah Yang dtenma olen Fisak KE EY ¢ akan ditanagurg wien FAK
# AT Peerage anoya fae tet yal yang btedma akar fenduk
# FyAU leat saat peas aka: deans bekena
#
#
#
# BBP PMAK BEB tanga 18! Perawarar ke
# ki
#
#
#
# done
